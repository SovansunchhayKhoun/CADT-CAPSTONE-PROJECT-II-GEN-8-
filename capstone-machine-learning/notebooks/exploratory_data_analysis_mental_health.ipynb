# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Exploring Data from Kaggle
#
# ### Mental Disorder Symptoms - SONI_KUMARI_04
# https://www.kaggle.com/datasets/sonisingh04/mental-disorder-symptoms
#
# #### About Dataset
# - File: Mental disorder symptoms.xlsx (637, 29)

# %%
file_path = "../data/external/mental_disorder_symptoms.xlsx" # File path for the dataset

mental_disorder_symptoms = pd.read_excel(file_path)
mental_disorder_symptoms
# Out:
#      ag+1:629e  feeling.nervous  panic  breathing.rapidly  sweating  \
# 0           23                1      0                  1         0
# 1           14                1      0                  1         0
# 2           25                0      0                  0         0
# 3           29                1      0                  0         0
# 4           32                1      1                  1         1
# ..         ...              ...    ...                ...       ...
# 632         23                1      0                  1         1
# 633         27                1      0                  1         0
# 634         19                0      1                  0         0
# 635         16                1      0                  0         0
# 636         14                1      0                  1         0
#
#      trouble.in.concentration  having.trouble.in.sleeping  \
# 0                           0                           1
# ...

# %%
mental_disorder_symptoms["Disorder"].unique()
# Out:
# array(['MDD', 'ASD', 'Loneliness', 'bipolar', 'anexiety', 'PTSD',
#        'sleeping disorder', 'psychotic deprission', 'eating disorder',
#        'ADHD', 'PDD', 'OCD'], dtype=object)

# %% [markdown]
# ## Dataset Mental Disorders
#
# https://www.kaggle.com/datasets/cid007/mental-disorder-classification
#
# #### About Dataset
# - File: Mental disorder symptoms.xlsx (121, 19)

# %%
file_path = "../data/external/Dataset-Mental-Disorders.csv" # File path for the dataset

mental_disorder_symptoms = pd.read_csv(file_path)
mental_disorder_symptoms
# Out:
#     Patient Number     Sadness    Euphoric  Exhausted Sleep dissorder  \
# 0       Patiant-01     Usually      Seldom  Sometimes       Sometimes
# 1       Patiant-02     Usually      Seldom    Usually       Sometimes
# 2       Patiant-03   Sometimes  Most-Often  Sometimes       Sometimes
# 3       Patiant-04     Usually      Seldom    Usually      Most-Often
# 4       Patiant-05     Usually     Usually  Sometimes       Sometimes
# ..             ...         ...         ...        ...             ...
# 115    Patiant-116  Most-Often      Seldom    Usually       Sometimes
# 116    Patiant-117   Sometimes   Sometimes  Sometimes          Seldom
# 117    Patiant-118     Usually   Sometimes    Usually       Sometimes
# 118    Patiant-119     Usually   Sometimes     Seldom          Seldom
# 119    Patiant-120   Sometimes     Usually     Seldom         Usually
#
#     Mood Swing Suicidal thoughts Anorxia Authority Respect Try-Explanation  \
# ...

# %%
mental_disorder_symptoms["Expert Diagnose"].unique()
# Out:
# array(['Bipolar Type-2', 'Depression', 'Bipolar Type-1', 'Normal'],
#       dtype=object)

# %% [markdown]
# ## Bipolar Disorder
#
# https://www.kaggle.com/datasets/rabailanees/bipolar-disorder/data
#
# #### About Dataset
# - File: Mental disorder symptoms.xlsx (163, 29)

# %%
file_path = "../data/external/Bipolar disorder.csv" # File path for the dataset

mental_disorder_symptoms = pd.read_csv(file_path)
mental_disorder_symptoms
# Out:
#                Timestamp              Email Address   Age   Gender  \
# 0    11/26/2023 20:47:16   bsdsf21a032@pucit.edu.pk  18-25  Female
# 1    11/26/2023 23:29:52  khadijazahra335@gmail.com  18-25  Female
# 2    11/26/2023 23:43:32      zohhazhar13@gmail.com  18-25  Female
# 3     11/27/2023 0:01:02   bsdsf21m029@pucit.edu.pk  18-25  Female
# 4     11/27/2023 0:06:35   bsdsf21a022@pucit.edu.pk  18-25  Female
# ..                   ...                        ...    ...     ...
# 158                  NaN                        NaN    NaN     NaN
# 159                  NaN                     #NAME?    NaN     NaN
# 160              females                         94    NaN     NaN
# 161                males                         60    NaN     NaN
# 162      age count 18-25                     #NAME?    NaN     NaN
#
#     Are you currently undergoing from diagnosis for bipolar disorder?  \
# 0                                                   No
# ...

# %% [markdown]
# ## Mental Health Dataset
# Exploring the Landscape of Mental Well-being: A Comprehensive Dataset Analysis
#
# https://www.kaggle.com/datasets/bhavikjikadara/mental-health-dataset
# - File: Mental disorder symptoms.xlsx (163, 29)
# #### About Dataset
#
# This dataset appears to contain a variety of features related to text analysis, sentiment analysis, and psychological indicators, likely derived from posts or text data. Some features include readability indices such as Automated Readability Index (ARI), Coleman Liau Index, and Flesch-Kincaid Grade Level, as well as sentiment analysis scores like sentiment compound, negative, neutral, and positive scores. Additionally, there are features related to psychological aspects such as economic stress, isolation, substance use, and domestic stress. The dataset seems to cover a wide range of linguistic, psychological, and behavioural attributes, potentially suitable for analyzing mental health-related topics in online communities or text data.
#
# #### Benefits of Dataset
#
# - Insight into Mental Health:
#
# The dataset provides valuable insights into mental health by analyzing linguistic patterns, sentiment, and psychological indicators in text data. Researchers and data scientists can gain a better understanding of how mental health issues manifest in online communication.
#
# - Predictive Modeling:
#
# With a wide range of features, including sentiment analysis scores and psychological indicators, the dataset offers opportunities for developing predictive models to identify or predict mental health outcomes based on textual data. This can be useful for early intervention and support.
#
# - Community Engagement:
#
# Mental health is a topic of increasing importance, and this dataset can foster community engagement on platforms like Kaggle. Data enthusiasts, researchers, and mental health professionals can collaborate to analyze the data and develop solutions to address mental health challenges.
#
# - Data-driven Insights:
#
# By analyzing the dataset, users can uncover correlations and patterns between linguistic features, sentiment, and mental health indicators. These insights can inform interventions, policies, and support systems aimed at promoting mental well-being.
#
# - Educational Resource:
#
# The dataset can serve as a valuable educational resource for teaching and learning about mental health analytics, sentiment analysis, and text mining techniques. It provides a real-world dataset for students and practitioners to apply data science skills in a meaningful context.

# %% [markdown]
# ### Load Data

# %%
file_path = "../data/external/Mental Health Dataset.csv" # File path for the dataset

mental_disorder_symptoms = pd.read_csv(file_path)
mental_disorder_symptoms
# Out:
#               Timestamp  Gender        Country Occupation self_employed  \
# 0       8/27/2014 11:29  Female  United States  Corporate           NaN
# 1       8/27/2014 11:31  Female  United States  Corporate           NaN
# 2       8/27/2014 11:32  Female  United States  Corporate           NaN
# 3       8/27/2014 11:37  Female  United States  Corporate            No
# 4       8/27/2014 11:43  Female  United States  Corporate            No
# ...                 ...     ...            ...        ...           ...
# 292359  7/27/2015 23:25    Male  United States   Business           Yes
# 292360   8/17/2015 9:38    Male   South Africa   Business            No
# 292361  8/25/2015 19:59    Male  United States   Business            No
# 292362   9/26/2015 1:07    Male  United States   Business            No
# 292363   2/1/2016 23:04    Male  United States   Business            No
#
#        family_history treatment Days_Indoors Growing_Stress Changes_Habits  \
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 mental_disorder_symptoms.hist()
#
# File ~\Documents\GitHub\capstone-machine-learning\venv\lib\site-packages\pandas\plotting\_core.py:251, in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, backend, legend, **kwargs)
#     164 """
#     165 Make a histogram of the DataFrame's columns.
#     166
#    (...)
#     248     >>> hist = df.hist(bins=3)
#     249 """
#     250 plot_backend = _get_plot_backend(backend)
# --> 251 return plot_backend.hist_frame(
#     252     data,
#     253     column=column,
#     254     by=by,
#     255     grid=grid,
#     256     xlabelsize=xlabelsize,
#     257     xrot=xrot,
#     258     ylabelsize=ylabelsize,
#     259     yrot=yrot,
#     260     ax=ax,
#     261     sharex=sharex,
# ...

# %% [markdown]
# https://www.kaggle.com/datasets/parvezalmuqtadir2348/postpartum-depression
# https://www.kaggle.com/datasets/muhammadshahidazeem/panic-disorder-detection-dataset
# https://www.kaggle.com/datasets/shree23yaa/schizophrenia-symptoms
# https://www.kaggle.com/datasets/karanbakshi1/mental-illness-dataset
